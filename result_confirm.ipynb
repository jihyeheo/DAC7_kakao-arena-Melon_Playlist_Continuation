# %%
results = pd.read_json("results.json")

# %%
import pandas as pd

# %%
results
# Out:
#            id                                              songs  \
# 0      147640  [348200, 443914, 362966, 518420, 553171, 44016...
# 1      149981  [213435, 222305, 383011, 166761, 701801, 49996...
# 2       82689  [663256, 140867, 177460, 554751, 686809, 41328...
# 3       39967  [443914, 518420, 704707, 588471, 326204, 45566...
# 4        7531  [144663, 675115, 396828, 701557, 520093, 65049...
# ...       ...                                                ...
# 23010    7433  [696494, 202185, 571790, 595181, 52192, 29793,...
# 23011  112943  [144663, 116573, 357367, 366786, 654757, 13314...
# 23012  134619  [357367, 174749, 461341, 169984, 348200, 50503...
# 23013  113348  [144663, 349492, 675115, 463173, 396828, 42155...
# 23014  132400  [705515, 321724, 335757, 205939, 650367, 15464...
#
#                                                 tags
# 0      [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 1      [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# ...

# %%
results['tags'][20000:20045]
# Out:
# 20000     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20001     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20002     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20003     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20004     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20005     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20006     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20007     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20008     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20009     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20010     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20011     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20012     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20013       [감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤, 카페]
# 20014     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20015     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# 20016     [기분전환, 감성, 휴식, 발라드, 잔잔한, 드라이브, 힐링, 사랑, 새벽, 밤]
# ...
